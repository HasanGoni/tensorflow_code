# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import os
import zipfile

import PIL.Image, PIL.ImageFont, PIL.ImageDraw
import numpy as np
from matplotlib import pyplot as plt

import tensorflow as tf
import tensorflow_datasets as tfds
from sklearn.model_selection import train_test_split

print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.3.1

# %%
# download zipped dataset
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/m2nist.zip \
    -O /tmp/m2nist.zip

# find and extract to a local folder ('/tmp/training')
local_zip = '/tmp/m2nist.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/training')
zip_ref.close()
# Out:
# --2020-12-27 11:19:46--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/m2nist.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 2a00:1450:4001:809::2010, 2a00:1450:4001:825::2010, 2a00:1450:4001:824::2010, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|2a00:1450:4001:809::2010|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17378168 (17M) [application/zip]
# Saving to: '/tmp/m2nist.zip’
#
# /tmp/m2nist.zip     100%[===================>]  16,57M  6,12MB/s    in 2,7s
#
# 2020-12-27 11:19:49 (6,12 MB/s) - '/tmp/m2nist.zip’ saved [17378168/17378168]

# %%
BATCH_SIZE = 32

def read_image_and_annotation(image, annotation):
  '''
  Casts the image and annotation to their expected data type and
  normalizes the input image so that each pixel is in the range [-1, 1]

  Args:
    image (numpy array) -- input image
    annotation (numpy array) -- ground truth label map

  Returns:
    preprocessed image-annotation pair
  '''

  image = tf.cast(image, dtype=tf.float32)
  image = tf.reshape(image, (image.shape[0], image.shape[1], 1,))
  annotation = tf.cast(annotation, dtype=tf.int32)
  image = image / 127.5
  image -= 1

  return image, annotation


def get_training_dataset(images, annos):
  '''
  Prepares shuffled batches of the training set.
  
  Args:
    images (list of strings) -- paths to each image file in the train set
    annos (list of strings) -- paths to each label map in the train set

  Returns:
    tf Dataset containing the preprocessed train set
  '''
  training_dataset = tf.data.Dataset.from_tensor_slices((images, annos))
  training_dataset = training_dataset.map(read_image_and_annotation)

  training_dataset = training_dataset.shuffle(512, reshuffle_each_iteration=True)
  training_dataset = training_dataset.batch(BATCH_SIZE)
  training_dataset = training_dataset.repeat()
  training_dataset = training_dataset.prefetch(-1)

  return training_dataset


def get_validation_dataset(images, annos):
  '''
  Prepares batches of the validation set.
  
  Args:
    images (list of strings) -- paths to each image file in the val set
    annos (list of strings) -- paths to each label map in the val set

  Returns:
    tf Dataset containing the preprocessed validation set
  '''
  validation_dataset = tf.data.Dataset.from_tensor_slices((images, annos))
  validation_dataset = validation_dataset.map(read_image_and_annotation)
  validation_dataset = validation_dataset.batch(BATCH_SIZE)
  validation_dataset = validation_dataset.repeat()

  return validation_dataset


def get_test_dataset(images, annos):
  '''
  Prepares batches of the test set.
  
  Args:
    images (list of strings) -- paths to each image file in the test set
    annos (list of strings) -- paths to each label map in the test set

  Returns:
    tf Dataset containing the preprocessed validation set
  '''
  test_dataset = tf.data.Dataset.from_tensor_slices((images, annos))
  test_dataset = test_dataset.map(read_image_and_annotation)
  test_dataset = test_dataset.batch(BATCH_SIZE, drop_remainder=True)

  return test_dataset


def load_images_and_segments():
  '''
  Loads the images and segments as numpy arrays from npy files 
  and makes splits for training, validation and test datasets.

  Returns:
    3 tuples containing the train, val, and test splits
  '''

  #Loads images and segmentation masks.
  images = np.load('/tmp/training/combined.npy')
  segments = np.load('/tmp/training/segmented.npy')

  #Makes training, validation, test splits from loaded images and segmentation masks.
  train_images, val_images, train_annos, val_annos = train_test_split(images, segments, test_size=0.2, shuffle=True)
  val_images, test_images, val_annos, test_annos = train_test_split(val_images, val_annos, test_size=0.2, shuffle=True)

  return (train_images, train_annos), (val_images, val_annos), (test_images, test_annos)

# %%
# Load Dataset
train_slices, val_slices, test_slices = load_images_and_segments()

# Create training, validation, test datasets.
training_dataset = get_training_dataset(train_slices[0], train_slices[1])
validation_dataset = get_validation_dataset(val_slices[0], val_slices[1])
test_dataset = get_test_dataset(test_slices[0], test_slices[1])

# %%
# Visualization Utilities

# there are 11 classes in the dataset: one class for each digit (0 to 9) plus the background class
n_classes = 11

# assign a random color for each class
colors = [tuple(np.random.randint(256, size=3) / 255.0) for i in range(n_classes)]

def fuse_with_pil(images):
  '''
  Creates a blank image and pastes input images

  Args:
    images (list of numpy arrays) - numpy array representations of the images to paste
  
  Returns:
    PIL Image object containing the images
  '''

  widths = (image.shape[1] for image in images)
  heights = (image.shape[0] for image in images)
  total_width = sum(widths)
  max_height = max(heights)

  new_im = PIL.Image.new('RGB', (total_width, max_height))

  x_offset = 0
  for im in images:
    pil_image = PIL.Image.fromarray(np.uint8(im))
    new_im.paste(pil_image, (x_offset,0))
    x_offset += im.shape[1]
  
  return new_im


def give_color_to_annotation(annotation):
  '''
  Converts a 2-D annotation to a numpy array with shape (height, width, 3) where
  the third axis represents the color channel. The label values are multiplied by
  255 and placed in this axis to give color to the annotation

  Args:
    annotation (numpy array) - label map array
  
  Returns:
    the annotation array with an additional color channel/axis
  '''
  seg_img = np.zeros( (annotation.shape[0],annotation.shape[1], 3) ).astype('float')
  
  for c in range(n_classes):
    segc = (annotation == c)
    seg_img[:,:,0] += segc*( colors[c][0] * 255.0)
    seg_img[:,:,1] += segc*( colors[c][1] * 255.0)
    seg_img[:,:,2] += segc*( colors[c][2] * 255.0)
  
  return seg_img


def show_annotation_and_prediction(image, annotation, prediction, iou_list, dice_score_list):
  '''
  Displays the images with the ground truth and predicted label maps. Also overlays the metrics.

  Args:
    image (numpy array) -- the input image
    annotation (numpy array) -- the ground truth label map
    prediction (numpy array) -- the predicted label map
    iou_list (list of floats) -- the IOU values for each class
    dice_score_list (list of floats) -- the Dice Score for each class
  '''

  new_ann = np.argmax(annotation, axis=2)
  true_img = give_color_to_annotation(new_ann)
  pred_img = give_color_to_annotation(prediction)

  image = image + 1
  image = image * 127.5
  image = np.reshape(image, (image.shape[0], image.shape[1],))
  image = np.uint8(image)
  images = [image, np.uint8(pred_img), np.uint8(true_img)]

  metrics_by_id = [(idx, iou, dice_score) for idx, (iou, dice_score) in enumerate(zip(iou_list, dice_score_list)) if iou > 0.0 and idx < 10]
  metrics_by_id.sort(key=lambda tup: tup[1], reverse=True)  # sorts in place

  display_string_list = ["{}: IOU: {} Dice Score: {}".format(idx, iou, dice_score) for idx, iou, dice_score in metrics_by_id]
  display_string = "\n".join(display_string_list)

  plt.figure(figsize=(15, 4))

  for idx, im in enumerate(images):
    plt.subplot(1, 3, idx+1)
    if idx == 1:
      plt.xlabel(display_string)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(im)


def show_annotation_and_image(image, annotation):
  '''
  Displays the image and its annotation side by side

  Args:
    image (numpy array) -- the input image
    annotation (numpy array) -- the label map
  '''
  new_ann = np.argmax(annotation, axis=2)
  seg_img = give_color_to_annotation(new_ann)
  
  image = image + 1
  image = image * 127.5
  image = np.reshape(image, (image.shape[0], image.shape[1],))

  image = np.uint8(image)
  images = [image, seg_img]
  
  images = [image, seg_img]
  fused_img = fuse_with_pil(images)
  plt.imshow(fused_img)


def list_show_annotation(dataset, num_images):
  '''
  Displays images and its annotations side by side

  Args:
    dataset (tf Dataset) -- batch of images and annotations
    num_images (int) -- number of images to display
  '''
  ds = dataset.unbatch()

  plt.figure(figsize=(20, 15))
  plt.title("Images And Annotations")
  plt.subplots_adjust(bottom=0.1, top=0.9, hspace=0.05)

  for idx, (image, annotation) in enumerate(ds.take(num_images)):
    plt.subplot(5, 5, idx + 1)
    plt.yticks([])
    plt.xticks([])
    show_annotation_and_image(image.numpy(), annotation.numpy())

# %%
# get 10 images from the training set
list_show_annotation(training_dataset, 10)

# %%
# get 10 images from the validation set
list_show_annotation(validation_dataset, 10)

# %%
# parameter describing where the channel dimension is found in our dataset
IMAGE_ORDERING = 'channels_last'

def conv_block(input, filters, strides, pooling_size, pool_strides):
  '''
  Args:
    input (tensor) -- batch of images or features
    filters (int) -- number of filters of the Conv2D layers
    strides (int) -- strides setting of the Conv2D layers
    pooling_size (int) -- pooling size of the MaxPooling2D layers
    pool_strides (int) -- strides setting of the MaxPooling2D layers
  
  Returns:
    (tensor) max pooled and batch-normalized features of the input 
  '''
  ### START CODE HERE ###
  # use the functional syntax to stack the layers as shown in the diagram above
  x = tf.keras.layers.Conv2D(filters=filters, kernel_size= (3,3), strides =strides, padding='same', data_format=IMAGE_ORDERING)(input)
  x = tf.keras.layers.LeakyReLU()(x)
  x = tf.keras.layers.Conv2D(filters=filters, kernel_size= (3,3), strides =strides, padding='same', data_format=IMAGE_ORDERING)(x)
  x = tf.keras.layers.LeakyReLU()(x)
  x = tf.keras.layers.MaxPooling2D(pool_size=pooling_size, strides=pool_strides, padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  ### END CODE HERE ###

  return x

# %%
# TEST CODE:

test_input = tf.keras.layers.Input(shape=(64,84, 1))
test_output = conv_block(test_input, 32, 3, 2, 2)
test_model = tf.keras.Model(inputs=test_input, outputs=test_output)

print(test_model.summary())

# free up test resources
del test_input, test_output, test_model
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 64, 84, 1)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 22, 28, 32)        320
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 22, 28, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 10, 32)         9248
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 10, 32)         0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 5, 32)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 5, 32)          128
# =================================================================
# Total params: 9,696
# Trainable params: 9,632
# Non-trainable params: 64
# _________________________________________________________________
# None

# %% [markdown]
# <a name='exercise-2'></a>
#
# #### **Exercise 2**
#
# Now that we've defined the building block of our encoder, you can now build the downsampling path. Please complete the function below to create the encoder. This should chain together five convolution building blocks to create a feature extraction CNN minus the fully connected layers.
#
# *Notes*:
# 1. To optimize processing, it is best to resize the images to have dimension sizes in the power of 2. We know that our dataset images have the size 64 x 84. 64 is already a power of 2. 84, on the other hand, is not and needs to be padded to 96. You can refer to the [ZeroPadding2D layer](https://keras.io/api/layers/reshaping_layers/zero_padding2d/) on how to do this. Remember that you will only pad the width (84) and not the height (64).
#
# 2. We recommend keeping the pool size and stride parameters constant at 2

# %%
def FCN8(input_height=64, input_width=84):
    '''
    Defines the downsampling path of the image segmentation model.

    Args:
      input_height (int) -- height of the images
      width (int) -- width of the images

    Returns:
    (tuple of tensors, tensor)
      tuple of tensors -- features extracted at blocks 3 to 5
      tensor -- copy of the input
    '''
   
    img_input = tf.keras.layers.Input(shape=(input_height,input_width, 1))
    ### START CODE HERE ###
    
    # pad the input image to have dimensions to the nearest power of two
    x = tf.keras.layers.ZeroPadding2D(padding=(0, 6))(img_input) 

    # Block 1
    x = conv_block(input=x, filters=32, strides=1, pooling_size=2, pool_strides=2)
  
    # Block 2
    x = conv_block(input=x, filters=64, strides=1, pooling_size=2, pool_strides=2)
  
    
    # Block 3
    x = conv_block(input=x, filters=128, strides=1, pooling_size=2, pool_strides=2)
    # save the feature map at this stage
    f3 = x

    # Block 4
    x = conv_block(input=x, filters=256, strides=1, pooling_size=2, pool_strides=2)
    # save the feature map at this stage
    f4 = x

    # Block 5
    x = conv_block(input=x, filters=256, strides=1, pooling_size=2, pool_strides=2)
  
    # save the feature map at this stage
    f5 = x

    ### END CODE HERE ###
  
    return (f3, f4, f5), img_input

# %%
test_convs, test_img_input = FCN8()
test_model = tf.keras.Model(inputs=test_img_input, outputs=[test_convs, test_img_input])

print(test_model.summary())

del test_convs, test_img_input, test_model
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 64, 84, 1)]       0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 64, 96, 1)         0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 64, 96, 32)        320
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 64, 96, 32)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 64, 96, 32)        9248
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 64, 96, 32)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 32, 48, 32)        0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 32, 48, 32)        128
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 32, 48, 64)        18496
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 32, 48, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 32, 48, 64)        36928
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 32, 48, 64)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 16, 24, 64)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 16, 24, 64)        256
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 16, 24, 128)       73856
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 16, 24, 128)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 16, 24, 128)       147584
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 16, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 8, 12, 128)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 8, 12, 128)        512
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 8, 12, 256)        295168
# _________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)   (None, 8, 12, 256)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 8, 12, 256)        590080
# _________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)   (None, 8, 12, 256)        0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 4, 6, 256)         0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 4, 6, 256)         1024
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 4, 6, 256)         590080
# _________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)   (None, 4, 6, 256)         0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 4, 6, 256)         590080
# _________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)   (None, 4, 6, 256)         0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 2, 3, 256)         0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 2, 3, 256)         1024
# =================================================================
# Total params: 2,354,784
# Trainable params: 2,353,312
# Non-trainable params: 1,472
# _________________________________________________________________
# None

# %%
def fcn8_decoder(convs, n_classes):
  # features from the encoder stage
  f3, f4, f5 = convs

  # number of filters
  n = 512

  # add convolutional layers on top of the CNN extractor.
  o = tf.keras.layers.Conv2D(n , (7 , 7) , activation='relu' , padding='same', name="conv6", data_format=IMAGE_ORDERING)(f5)
  o = tf.keras.layers.Dropout(0.5)(o)

  o = tf.keras.layers.Conv2D(n , (1 , 1) , activation='relu' , padding='same', name="conv7", data_format=IMAGE_ORDERING)(o)
  o = tf.keras.layers.Dropout(0.5)(o)

  o = tf.keras.layers.Conv2D(n_classes,  (1, 1), activation='relu' , padding='same', data_format=IMAGE_ORDERING)(o)

    
  ### START CODE HERE ###

  # Upsample `o` above and crop any extra pixels introduced
  o = tf.keras.layers.Conv2DTranspose(
               n_classes, kernel_size=(4, 4),
               strides=(2, 2),
               use_bias=False)(f5)
  o = tf.keras.layers.Cropping2D(
               cropping=(1, 1))(o)

  # load the pool 4 prediction and do a 1x1 convolution to reshape it to the same shape of `o` above
  o2 = f4
  o2 = tf.keras.layers.Conv2D(
               n_classes,
               (1, 1),
               activation='relu',
               padding='same')(f4)

  # add the results of the upsampling and pool 4 prediction
  o = tf.keras.layers.Add()([o, o2])

  # upsample the resulting tensor of the operation you just did
  o = tf.keras.layers.Conv2DTranspose(
              n_classes, (4, 4),
              strides=(2, 2),
              use_bias=False)(o)
  o = tf.keras.layers.Cropping2D(
             cropping=(1, 1))(o)

  # load the pool 3 prediction and do a 1x1 convolution to reshape it to the same shape of `o` above
  o2 = f3
  o2 = tf.keras.layers.Conv2D(n_classes , ( 1 , 1 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING)(o2)

  # add the results of the upsampling and pool 3 prediction
  o = tf.keras.layers.Add()([o, o2])

  # upsample up to the size of the original image
  o = tf.keras.layers.Conv2DTranspose(
            n_classes,
            (8, 8),
            strides=(8, 8),
            use_bias=False)(o)
  o = tf.keras.layers.Cropping2D(((0, 0), (0, 96-84)))(o)

  # append a sigmoid activation
  o = (tf.keras.layers.Activation('sigmoid'))(o)
  ### END CODE HERE ###

  return o

# %%
# TEST CODE

test_convs, test_img_input = FCN8()
test_fcn8_decoder = fcn8_decoder(test_convs, 11)

print(test_fcn8_decoder.shape)

del test_convs, test_img_input, test_fcn8_decoder
# Out:
# (None, 64, 84, 11)

# %%
# start the encoder using the default input size 64 x 84
convs, img_input = FCN8()

# pass the convolutions obtained in the encoder to the decoder
dec_op = fcn8_decoder(convs, n_classes)

# define the model specifying the input (batch of images) and output (decoder output)
model = tf.keras.Model(inputs = img_input, outputs = dec_op)

# %%
sgd = tf.keras.optimizers.SGD(lr=1E-2, momentum=0.9, nesterov=True)
### START CODE HERE ###
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
### END CODE HERE ###

# %%
### START CODE HERE ###
EPOCHS = 200
### END CODE HERE ###

steps_per_epoch = 4000//BATCH_SIZE
validation_steps = 800//BATCH_SIZE
test_steps = 200//BATCH_SIZE


history = model.fit(training_dataset,
                    steps_per_epoch=steps_per_epoch, validation_data=validation_dataset, validation_steps=validation_steps, epochs=EPOCHS)
# Out:
# Epoch 1/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0472 - accuracy: 0.9669 - val_loss: 0.0652 - val_accuracy: 0.9637
# Epoch 2/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0470 - accuracy: 0.9670 - val_loss: 0.0648 - val_accuracy: 0.9637
# Epoch 3/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0469 - accuracy: 0.9670 - val_loss: 0.0657 - val_accuracy: 0.9636
# Epoch 4/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0468 - accuracy: 0.9670 - val_loss: 0.0655 - val_accuracy: 0.9637
# Epoch 5/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0468 - accuracy: 0.9670 - val_loss: 0.0637 - val_accuracy: 0.9640
# Epoch 6/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0466 - accuracy: 0.9671 - val_loss: 0.0646 - val_accuracy: 0.9639
# Epoch 7/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0465 - accuracy: 0.9671 - val_loss: 0.0652 - val_accuracy: 0.9638
# Epoch 8/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0464 - accuracy: 0.9671 - val_loss: 0.0653 - val_accuracy: 0.9637
# Epoch 9/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0463 - accuracy: 0.9671 - val_loss: 0.0693 - val_accuracy: 0.9633
# Epoch 10/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0462 - accuracy: 0.9671 - val_loss: 0.0634 - val_accuracy: 0.9641
# Epoch 11/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0461 - accuracy: 0.9672 - val_loss: 0.0650 - val_accuracy: 0.9638
# Epoch 12/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0459 - accuracy: 0.9672 - val_loss: 0.0663 - val_accuracy: 0.9635
# Epoch 13/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0459 - accuracy: 0.9672 - val_loss: 0.0647 - val_accuracy: 0.9638
# Epoch 14/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0459 - accuracy: 0.9672 - val_loss: 0.0638 - val_accuracy: 0.9641
# Epoch 15/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0458 - accuracy: 0.9672 - val_loss: 0.0664 - val_accuracy: 0.9636
# Epoch 16/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0457 - accuracy: 0.9673 - val_loss: 0.0645 - val_accuracy: 0.9640
# Epoch 17/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0456 - accuracy: 0.9673 - val_loss: 0.0657 - val_accuracy: 0.9637
# Epoch 18/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0456 - accuracy: 0.9673 - val_loss: 0.0632 - val_accuracy: 0.9641
# Epoch 19/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0454 - accuracy: 0.9673 - val_loss: 0.0700 - val_accuracy: 0.9631
# Epoch 20/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0453 - accuracy: 0.9674 - val_loss: 0.0639 - val_accuracy: 0.9640
# Epoch 21/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0453 - accuracy: 0.9674 - val_loss: 0.0641 - val_accuracy: 0.9640
# Epoch 22/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0452 - accuracy: 0.9674 - val_loss: 0.0658 - val_accuracy: 0.9638
# Epoch 23/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0451 - accuracy: 0.9674 - val_loss: 0.0635 - val_accuracy: 0.9641
# Epoch 24/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0450 - accuracy: 0.9674 - val_loss: 0.0638 - val_accuracy: 0.9641
# Epoch 25/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0450 - accuracy: 0.9674 - val_loss: 0.0619 - val_accuracy: 0.9644
# Epoch 26/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0448 - accuracy: 0.9675 - val_loss: 0.0632 - val_accuracy: 0.9642
# Epoch 27/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0449 - accuracy: 0.9675 - val_loss: 0.0650 - val_accuracy: 0.9640
# Epoch 28/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0447 - accuracy: 0.9675 - val_loss: 0.0618 - val_accuracy: 0.9644
# Epoch 29/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0445 - accuracy: 0.9675 - val_loss: 0.0742 - val_accuracy: 0.9627
# Epoch 30/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0446 - accuracy: 0.9675 - val_loss: 0.0627 - val_accuracy: 0.9643
# Epoch 31/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0445 - accuracy: 0.9675 - val_loss: 0.0630 - val_accuracy: 0.9643
# Epoch 32/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0444 - accuracy: 0.9676 - val_loss: 0.0643 - val_accuracy: 0.9640
# Epoch 33/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0443 - accuracy: 0.9676 - val_loss: 0.0625 - val_accuracy: 0.9644
# Epoch 34/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0443 - accuracy: 0.9676 - val_loss: 0.0629 - val_accuracy: 0.9643
# Epoch 35/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0442 - accuracy: 0.9676 - val_loss: 0.0640 - val_accuracy: 0.9641
# Epoch 36/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0441 - accuracy: 0.9677 - val_loss: 0.0619 - val_accuracy: 0.9644
# Epoch 37/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0440 - accuracy: 0.9677 - val_loss: 0.0628 - val_accuracy: 0.9645
# Epoch 38/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0439 - accuracy: 0.9677 - val_loss: 0.0630 - val_accuracy: 0.9644
# Epoch 39/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0439 - accuracy: 0.9677 - val_loss: 0.0614 - val_accuracy: 0.9646
# Epoch 40/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0439 - accuracy: 0.9677 - val_loss: 0.0673 - val_accuracy: 0.9637
# Epoch 41/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0438 - accuracy: 0.9677 - val_loss: 0.0627 - val_accuracy: 0.9644
# Epoch 42/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0437 - accuracy: 0.9677 - val_loss: 0.0631 - val_accuracy: 0.9644
# Epoch 43/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0436 - accuracy: 0.9677 - val_loss: 0.0626 - val_accuracy: 0.9644
# Epoch 44/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0436 - accuracy: 0.9678 - val_loss: 0.0632 - val_accuracy: 0.9644
# Epoch 45/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0435 - accuracy: 0.9678 - val_loss: 0.0620 - val_accuracy: 0.9645
# Epoch 46/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0433 - accuracy: 0.9678 - val_loss: 0.0656 - val_accuracy: 0.9641
# Epoch 47/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0433 - accuracy: 0.9678 - val_loss: 0.0623 - val_accuracy: 0.9646
# Epoch 48/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0432 - accuracy: 0.9678 - val_loss: 0.0617 - val_accuracy: 0.9646
# Epoch 49/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0432 - accuracy: 0.9678 - val_loss: 0.0625 - val_accuracy: 0.9646
# Epoch 50/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0431 - accuracy: 0.9679 - val_loss: 0.0636 - val_accuracy: 0.9644
# Epoch 51/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0431 - accuracy: 0.9679 - val_loss: 0.0620 - val_accuracy: 0.9646
# Epoch 52/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0431 - accuracy: 0.9679 - val_loss: 0.0610 - val_accuracy: 0.9647
# Epoch 53/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0429 - accuracy: 0.9679 - val_loss: 0.0612 - val_accuracy: 0.9647
# Epoch 54/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0428 - accuracy: 0.9679 - val_loss: 0.0615 - val_accuracy: 0.9647
# Epoch 55/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0428 - accuracy: 0.9679 - val_loss: 0.0630 - val_accuracy: 0.9645
# Epoch 56/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0428 - accuracy: 0.9679 - val_loss: 0.0624 - val_accuracy: 0.9645
# Epoch 57/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0427 - accuracy: 0.9680 - val_loss: 0.0612 - val_accuracy: 0.9648
# Epoch 58/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0427 - accuracy: 0.9680 - val_loss: 0.0622 - val_accuracy: 0.9645
# Epoch 59/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0426 - accuracy: 0.9680 - val_loss: 0.0620 - val_accuracy: 0.9646
# Epoch 60/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0425 - accuracy: 0.9680 - val_loss: 0.0641 - val_accuracy: 0.9644
# Epoch 61/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0425 - accuracy: 0.9680 - val_loss: 0.0623 - val_accuracy: 0.9647
# Epoch 62/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0424 - accuracy: 0.9680 - val_loss: 0.0631 - val_accuracy: 0.9644
# Epoch 63/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0423 - accuracy: 0.9680 - val_loss: 0.0615 - val_accuracy: 0.9648
# Epoch 64/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0422 - accuracy: 0.9681 - val_loss: 0.0614 - val_accuracy: 0.9648
# Epoch 65/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0422 - accuracy: 0.9681 - val_loss: 0.0640 - val_accuracy: 0.9644
# Epoch 66/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0422 - accuracy: 0.9681 - val_loss: 0.0620 - val_accuracy: 0.9647
# Epoch 67/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0422 - accuracy: 0.9681 - val_loss: 0.0609 - val_accuracy: 0.9649
# Epoch 68/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0421 - accuracy: 0.9681 - val_loss: 0.0618 - val_accuracy: 0.9647
# Epoch 69/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0420 - accuracy: 0.9681 - val_loss: 0.0607 - val_accuracy: 0.9649
# Epoch 70/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0419 - accuracy: 0.9681 - val_loss: 0.0608 - val_accuracy: 0.9649
# Epoch 71/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0419 - accuracy: 0.9681 - val_loss: 0.0634 - val_accuracy: 0.9645
# Epoch 72/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0419 - accuracy: 0.9681 - val_loss: 0.0621 - val_accuracy: 0.9646
# Epoch 73/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0418 - accuracy: 0.9682 - val_loss: 0.0615 - val_accuracy: 0.9648
# Epoch 74/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0418 - accuracy: 0.9682 - val_loss: 0.0612 - val_accuracy: 0.9649
# Epoch 75/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0418 - accuracy: 0.9682 - val_loss: 0.0611 - val_accuracy: 0.9649
# Epoch 76/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0417 - accuracy: 0.9682 - val_loss: 0.0623 - val_accuracy: 0.9647
# Epoch 77/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0416 - accuracy: 0.9682 - val_loss: 0.0638 - val_accuracy: 0.9645
# Epoch 78/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0415 - accuracy: 0.9682 - val_loss: 0.0628 - val_accuracy: 0.9647
# Epoch 79/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0415 - accuracy: 0.9682 - val_loss: 0.0605 - val_accuracy: 0.9650
# Epoch 80/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0415 - accuracy: 0.9682 - val_loss: 0.0632 - val_accuracy: 0.9647
# Epoch 81/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0414 - accuracy: 0.9682 - val_loss: 0.0645 - val_accuracy: 0.9644
# Epoch 82/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0413 - accuracy: 0.9683 - val_loss: 0.0613 - val_accuracy: 0.9649
# Epoch 83/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0414 - accuracy: 0.9683 - val_loss: 0.0604 - val_accuracy: 0.9650
# Epoch 84/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0413 - accuracy: 0.9683 - val_loss: 0.0609 - val_accuracy: 0.9649
# Epoch 85/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0413 - accuracy: 0.9683 - val_loss: 0.0616 - val_accuracy: 0.9648
# Epoch 86/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0412 - accuracy: 0.9683 - val_loss: 0.0610 - val_accuracy: 0.9650
# Epoch 87/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0411 - accuracy: 0.9683 - val_loss: 0.0617 - val_accuracy: 0.9649
# Epoch 88/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0411 - accuracy: 0.9683 - val_loss: 0.0607 - val_accuracy: 0.9650
# Epoch 89/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0410 - accuracy: 0.9684 - val_loss: 0.0617 - val_accuracy: 0.9649
# Epoch 90/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0409 - accuracy: 0.9684 - val_loss: 0.0606 - val_accuracy: 0.9650
# Epoch 91/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0409 - accuracy: 0.9684 - val_loss: 0.0619 - val_accuracy: 0.9648
# Epoch 92/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0409 - accuracy: 0.9684 - val_loss: 0.0624 - val_accuracy: 0.9648
# Epoch 93/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0408 - accuracy: 0.9684 - val_loss: 0.0608 - val_accuracy: 0.9650
# Epoch 94/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0408 - accuracy: 0.9684 - val_loss: 0.0609 - val_accuracy: 0.9650
# Epoch 95/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0407 - accuracy: 0.9684 - val_loss: 0.0628 - val_accuracy: 0.9648
# Epoch 96/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0407 - accuracy: 0.9684 - val_loss: 0.0630 - val_accuracy: 0.9647
# Epoch 97/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0407 - accuracy: 0.9684 - val_loss: 0.0605 - val_accuracy: 0.9651
# Epoch 98/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0407 - accuracy: 0.9684 - val_loss: 0.0613 - val_accuracy: 0.9650
# Epoch 99/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0406 - accuracy: 0.9684 - val_loss: 0.0601 - val_accuracy: 0.9652
# Epoch 100/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0405 - accuracy: 0.9685 - val_loss: 0.0600 - val_accuracy: 0.9652
# Epoch 101/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0406 - accuracy: 0.9685 - val_loss: 0.0640 - val_accuracy: 0.9646
# Epoch 102/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0405 - accuracy: 0.9685 - val_loss: 0.0610 - val_accuracy: 0.9651
# Epoch 103/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0404 - accuracy: 0.9685 - val_loss: 0.0605 - val_accuracy: 0.9651
# Epoch 104/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0403 - accuracy: 0.9685 - val_loss: 0.0619 - val_accuracy: 0.9649
# Epoch 105/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0403 - accuracy: 0.9685 - val_loss: 0.0604 - val_accuracy: 0.9652
# Epoch 106/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0402 - accuracy: 0.9685 - val_loss: 0.0604 - val_accuracy: 0.9651
# Epoch 107/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0402 - accuracy: 0.9685 - val_loss: 0.0605 - val_accuracy: 0.9651
# Epoch 108/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0402 - accuracy: 0.9685 - val_loss: 0.0611 - val_accuracy: 0.9651
# Epoch 109/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0402 - accuracy: 0.9685 - val_loss: 0.0611 - val_accuracy: 0.9650
# Epoch 110/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0402 - accuracy: 0.9685 - val_loss: 0.0607 - val_accuracy: 0.9651
# Epoch 111/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0401 - accuracy: 0.9686 - val_loss: 0.0623 - val_accuracy: 0.9649
# Epoch 112/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0400 - accuracy: 0.9686 - val_loss: 0.0607 - val_accuracy: 0.9651
# Epoch 113/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0400 - accuracy: 0.9686 - val_loss: 0.0598 - val_accuracy: 0.9652
# Epoch 114/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0399 - accuracy: 0.9686 - val_loss: 0.0618 - val_accuracy: 0.9650
# Epoch 115/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0399 - accuracy: 0.9686 - val_loss: 0.0610 - val_accuracy: 0.9651
# Epoch 116/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0398 - accuracy: 0.9686 - val_loss: 0.0596 - val_accuracy: 0.9653
# Epoch 117/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0398 - accuracy: 0.9687 - val_loss: 0.0607 - val_accuracy: 0.9651
# Epoch 118/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0398 - accuracy: 0.9687 - val_loss: 0.0604 - val_accuracy: 0.9652
# Epoch 119/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0397 - accuracy: 0.9687 - val_loss: 0.0607 - val_accuracy: 0.9652
# Epoch 120/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0397 - accuracy: 0.9687 - val_loss: 0.0621 - val_accuracy: 0.9650
# Epoch 121/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0396 - accuracy: 0.9687 - val_loss: 0.0610 - val_accuracy: 0.9652
# Epoch 122/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0397 - accuracy: 0.9687 - val_loss: 0.0595 - val_accuracy: 0.9654
# Epoch 123/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0395 - accuracy: 0.9688 - val_loss: 0.0607 - val_accuracy: 0.9652
# Epoch 124/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0395 - accuracy: 0.9688 - val_loss: 0.0602 - val_accuracy: 0.9653
# Epoch 125/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0395 - accuracy: 0.9688 - val_loss: 0.0598 - val_accuracy: 0.9654
# Epoch 126/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0395 - accuracy: 0.9688 - val_loss: 0.0607 - val_accuracy: 0.9653
# Epoch 127/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0394 - accuracy: 0.9688 - val_loss: 0.0597 - val_accuracy: 0.9655
# Epoch 128/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0394 - accuracy: 0.9688 - val_loss: 0.0601 - val_accuracy: 0.9653
# Epoch 129/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0393 - accuracy: 0.9688 - val_loss: 0.0598 - val_accuracy: 0.9654
# Epoch 130/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0393 - accuracy: 0.9689 - val_loss: 0.0611 - val_accuracy: 0.9652
# Epoch 131/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0393 - accuracy: 0.9689 - val_loss: 0.0600 - val_accuracy: 0.9654
# Epoch 132/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0393 - accuracy: 0.9689 - val_loss: 0.0620 - val_accuracy: 0.9652
# Epoch 133/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0392 - accuracy: 0.9689 - val_loss: 0.0608 - val_accuracy: 0.9653
# Epoch 134/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0392 - accuracy: 0.9689 - val_loss: 0.0600 - val_accuracy: 0.9654
# Epoch 135/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0392 - accuracy: 0.9689 - val_loss: 0.0613 - val_accuracy: 0.9653
# Epoch 136/200
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0391 - accuracy: 0.9689 - val_loss: 0.0599 - val_accuracy: 0.9654
# Epoch 137/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0391 - accuracy: 0.9689 - val_loss: 0.0607 - val_accuracy: 0.9654
# Epoch 138/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0390 - accuracy: 0.9690 - val_loss: 0.0600 - val_accuracy: 0.9654
# Epoch 139/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0390 - accuracy: 0.9690 - val_loss: 0.0609 - val_accuracy: 0.9653
# Epoch 140/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0389 - accuracy: 0.9690 - val_loss: 0.0617 - val_accuracy: 0.9653
# Epoch 141/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0389 - accuracy: 0.9690 - val_loss: 0.0607 - val_accuracy: 0.9654
# Epoch 142/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0389 - accuracy: 0.9690 - val_loss: 0.0610 - val_accuracy: 0.9654
# Epoch 143/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0388 - accuracy: 0.9691 - val_loss: 0.0602 - val_accuracy: 0.9656
# Epoch 144/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0388 - accuracy: 0.9691 - val_loss: 0.0604 - val_accuracy: 0.9655
# Epoch 145/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0388 - accuracy: 0.9691 - val_loss: 0.0602 - val_accuracy: 0.9655
# Epoch 146/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0387 - accuracy: 0.9691 - val_loss: 0.0591 - val_accuracy: 0.9656
# Epoch 147/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0387 - accuracy: 0.9691 - val_loss: 0.0605 - val_accuracy: 0.9655
# Epoch 148/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0386 - accuracy: 0.9692 - val_loss: 0.0598 - val_accuracy: 0.9656
# Epoch 149/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0386 - accuracy: 0.9692 - val_loss: 0.0608 - val_accuracy: 0.9655
# Epoch 150/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0386 - accuracy: 0.9692 - val_loss: 0.0598 - val_accuracy: 0.9657
# Epoch 151/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0385 - accuracy: 0.9693 - val_loss: 0.0605 - val_accuracy: 0.9656
# Epoch 152/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0384 - accuracy: 0.9693 - val_loss: 0.0596 - val_accuracy: 0.9658
# Epoch 153/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0384 - accuracy: 0.9693 - val_loss: 0.0599 - val_accuracy: 0.9658
# Epoch 154/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0384 - accuracy: 0.9694 - val_loss: 0.0593 - val_accuracy: 0.9659
# Epoch 155/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0383 - accuracy: 0.9694 - val_loss: 0.0603 - val_accuracy: 0.9656
# Epoch 156/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0383 - accuracy: 0.9694 - val_loss: 0.0599 - val_accuracy: 0.9659
# Epoch 157/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0382 - accuracy: 0.9695 - val_loss: 0.0625 - val_accuracy: 0.9655
# Epoch 158/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0381 - accuracy: 0.9695 - val_loss: 0.0602 - val_accuracy: 0.9658
# Epoch 159/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0381 - accuracy: 0.9695 - val_loss: 0.0594 - val_accuracy: 0.9659
# Epoch 160/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0380 - accuracy: 0.9696 - val_loss: 0.0597 - val_accuracy: 0.9659
# Epoch 161/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0380 - accuracy: 0.9696 - val_loss: 0.0596 - val_accuracy: 0.9659
# Epoch 162/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0379 - accuracy: 0.9696 - val_loss: 0.0591 - val_accuracy: 0.9660
# Epoch 163/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0379 - accuracy: 0.9696 - val_loss: 0.0609 - val_accuracy: 0.9658
# Epoch 164/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0378 - accuracy: 0.9696 - val_loss: 0.0604 - val_accuracy: 0.9658
# Epoch 165/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0378 - accuracy: 0.9696 - val_loss: 0.0596 - val_accuracy: 0.9659
# Epoch 166/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0378 - accuracy: 0.9696 - val_loss: 0.0592 - val_accuracy: 0.9660
# Epoch 167/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0378 - accuracy: 0.9697 - val_loss: 0.0596 - val_accuracy: 0.9659
# Epoch 168/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0377 - accuracy: 0.9697 - val_loss: 0.0593 - val_accuracy: 0.9659
# Epoch 169/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0377 - accuracy: 0.9697 - val_loss: 0.0599 - val_accuracy: 0.9659
# Epoch 170/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0376 - accuracy: 0.9697 - val_loss: 0.0617 - val_accuracy: 0.9656
# Epoch 171/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0376 - accuracy: 0.9697 - val_loss: 0.0589 - val_accuracy: 0.9660
# Epoch 172/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0376 - accuracy: 0.9697 - val_loss: 0.0597 - val_accuracy: 0.9659
# Epoch 173/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0376 - accuracy: 0.9697 - val_loss: 0.0593 - val_accuracy: 0.9660
# Epoch 174/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0375 - accuracy: 0.9697 - val_loss: 0.0601 - val_accuracy: 0.9659
# Epoch 175/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0375 - accuracy: 0.9697 - val_loss: 0.0599 - val_accuracy: 0.9659
# Epoch 176/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0375 - accuracy: 0.9697 - val_loss: 0.0591 - val_accuracy: 0.9661
# Epoch 177/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0374 - accuracy: 0.9697 - val_loss: 0.0607 - val_accuracy: 0.9659
# Epoch 178/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0374 - accuracy: 0.9697 - val_loss: 0.0597 - val_accuracy: 0.9660
# Epoch 179/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0373 - accuracy: 0.9698 - val_loss: 0.0604 - val_accuracy: 0.9659
# Epoch 180/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0374 - accuracy: 0.9697 - val_loss: 0.0593 - val_accuracy: 0.9660
# Epoch 181/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0373 - accuracy: 0.9698 - val_loss: 0.0598 - val_accuracy: 0.9659
# Epoch 182/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0373 - accuracy: 0.9698 - val_loss: 0.0590 - val_accuracy: 0.9661
# Epoch 183/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0372 - accuracy: 0.9698 - val_loss: 0.0597 - val_accuracy: 0.9660
# Epoch 184/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0372 - accuracy: 0.9698 - val_loss: 0.0588 - val_accuracy: 0.9661
# Epoch 185/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0372 - accuracy: 0.9698 - val_loss: 0.0612 - val_accuracy: 0.9657
# Epoch 186/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0372 - accuracy: 0.9698 - val_loss: 0.0592 - val_accuracy: 0.9661
# Epoch 187/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0372 - accuracy: 0.9698 - val_loss: 0.0628 - val_accuracy: 0.9656
# Epoch 188/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0372 - accuracy: 0.9698 - val_loss: 0.0591 - val_accuracy: 0.9660
# Epoch 189/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0371 - accuracy: 0.9698 - val_loss: 0.0595 - val_accuracy: 0.9660
# Epoch 190/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0371 - accuracy: 0.9698 - val_loss: 0.0596 - val_accuracy: 0.9660
# Epoch 191/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0370 - accuracy: 0.9698 - val_loss: 0.0593 - val_accuracy: 0.9661
# Epoch 192/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0370 - accuracy: 0.9698 - val_loss: 0.0592 - val_accuracy: 0.9660
# Epoch 193/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0370 - accuracy: 0.9698 - val_loss: 0.0594 - val_accuracy: 0.9661
# Epoch 194/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0369 - accuracy: 0.9699 - val_loss: 0.0601 - val_accuracy: 0.9660
# Epoch 195/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0370 - accuracy: 0.9698 - val_loss: 0.0606 - val_accuracy: 0.9659
# Epoch 196/200
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0369 - accuracy: 0.9699 - val_loss: 0.0604 - val_accuracy: 0.9660
# Epoch 197/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0368 - accuracy: 0.9699 - val_loss: 0.0592 - val_accuracy: 0.9661
# Epoch 198/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0368 - accuracy: 0.9699 - val_loss: 0.0585 - val_accuracy: 0.9662
# Epoch 199/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0368 - accuracy: 0.9699 - val_loss: 0.0590 - val_accuracy: 0.9661
# Epoch 200/200
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0368 - accuracy: 0.9699 - val_loss: 0.0601 - val_accuracy: 0.9661

# %%
results = model.predict(test_dataset, steps=test_steps)

print(results.shape)
# Out:
# (192, 64, 84, 11)

# %%
results = np.argmax(results, axis=3)

print(results.shape)
# Out:
# (192, 64, 84)

# %% [markdown]
# ### Metrics
#
# We showed in the lectures two ways to evaluate your predictions. The *intersection over union (IOU)* and the *dice score*. Recall that:
#
# $$IOU = \frac{area\_of\_overlap}{area\_of\_union}$$
# <br>
# $$Dice Score = 2 * \frac{area\_of\_overlap}{combined\_area}$$
#
# The code below does that for you as you've also seen in the ungraded lab. A small smoothing factor is introduced in the denominators to prevent possible division by zero.

# %%
print(results[0,0,0])

# prediction map for image 0
print(results[0,:,:])
# Out:
# 10
# [[10 10 10 ... 10 10 10]
#  [10 10 10 ... 10 10 10]
#  [10 10 10 ... 10 10 10]
#  ...
#  [10 10 10 ... 10 10 10]
#  [10 10 10 ... 10 10 10]
#  [10 10 10 ... 10 10 10]]

# %%
def class_wise_metrics(y_true, y_pred):
  '''
  Computes the class-wise IOU and Dice Score.

  Args:
    y_true (tensor) - ground truth label maps
    y_pred (tensor) - predicted label maps
  '''
  class_wise_iou = []
  class_wise_dice_score = []

  smoothing_factor = 0.00001

  for i in range(n_classes):
    intersection = np.sum((y_pred == i) * (y_true == i))
    y_true_area = np.sum((y_true == i))
    y_pred_area = np.sum((y_pred == i))
    combined_area = y_true_area + y_pred_area
    
    iou = (intersection) / (combined_area - intersection + smoothing_factor)
    class_wise_iou.append(iou)
    
    dice_score =  2 * ((intersection) / (combined_area + smoothing_factor))
    class_wise_dice_score.append(dice_score)

  return class_wise_iou, class_wise_dice_score

# %%
# place a number here between 0 to 191 to pick an image from the test set
integer_slider = 105

ds = test_dataset.unbatch()
ds = ds.batch(200)
images = []

y_true_segments = []
for image, annotation in ds.take(2):
  y_true_segments = annotation
  images = image
  
  
iou, dice_score = class_wise_metrics(np.argmax(y_true_segments[integer_slider], axis=2), results[integer_slider])  
show_annotation_and_prediction(image[integer_slider], annotation[integer_slider], results[integer_slider], iou, dice_score)

# %%
cls_wise_iou, cls_wise_dice_score = class_wise_metrics(np.argmax(y_true_segments, axis=3), results)

average_iou = 0.0
for idx, (iou, dice_score) in enumerate(zip(cls_wise_iou[:-1], cls_wise_dice_score[:-1])):
  print("Digit {}: IOU: {} Dice Score: {}".format(idx, iou, dice_score)) 
  average_iou += iou

grade = average_iou * 10

print("\nGrade is " + str(grade))

PASSING_GRADE = 60
if (grade>PASSING_GRADE):
  print("You passed!")
else:
  print("You failed. Please check your model and re-train")
# Out:
# Digit 0: IOU: 0.4356275296589028 Dice Score: 0.6068809919832138
# Digit 1: IOU: 0.41971296934819124 Dice Score: 0.5912645420727359
# Digit 2: IOU: 0.39676556371988625 Dice Score: 0.5681204835308431
# Digit 3: IOU: 0.39937200897223085 Dice Score: 0.570787476684702
# Digit 4: IOU: 0.3734439825869317 Dice Score: 0.5438066456609848
# Digit 5: IOU: 0.34793089524320836 Dice Score: 0.5162444105570129
# Digit 6: IOU: 0.4105705700773927 Dice Score: 0.5821340368030877
# Digit 7: IOU: 0.4472619781467611 Dice Score: 0.618080188521896
# Digit 8: IOU: 0.3732165554835195 Dice Score: 0.5435654762436318
# Digit 9: IOU: 0.3797961625003055 Dice Score: 0.5505105360085699
#
# Grade is 39.8369821573733
# You failed. Please check your model and re-train

# %%
model.save("model.h5")

# %%
# You can also use this cell as a shortcut for downloading your model
#from google.colab import files
#files.download("model.h5")
